# %%
# Import Dependencies
import requests
from config import api_key
import censusdata
import pandas as pd  
from sqlalchemy import create_engine
from config import remote_db_endpoint, remote_db_port
from config import remote_db_name, remote_db_user, remote_db_pwd
import numpy as np
from sqlalchemy import func
from sqlalchemy import distinct
import json
import psycopg2
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
cloud_engine = create_engine(f"postgresql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
cloud_conn = cloud_engine.connect()

ca_school_data = pd.read_sql('select * from sd_master_df', cloud_conn)

ca_school_data.head()
# Out:
#   zipcode  Total Students Enrolled  Average_School_Rating  \
# 0   91901                   1560.0               5.953846
# 1   91902                   1372.0               6.148688
# 2   91906                    454.0               4.279736
# 3   91910                  15136.0               6.237381
# 4   91911                  14330.0               5.293859
#
#    MEDIAN HOUSEHOLD INCOME  MEDIAN INCOME BLACK/AA  \
# 0                  79859.0                143917.0
# 1                  86913.0                113875.0
# 2                  49276.0                     0.0
# 3                  53890.0                 54475.0
# 4                  49156.0                 42902.0
#
#    MEDIAN INCOME INDIGENOUS PEOPLE  MEDIAN INCOME ASIAN  \
# 0                          53750.0              78625.0
# 1                              0.0              80192.0
# 2                          24306.0                  0.0
# 3                          43287.0              69688.0
# 4                          36932.0              77083.0
#
#    MEDIAN INCOME HAW/PAC ISLANDER  MEDIAN INCOME OTHER RACE  \
# 0                             0.0                   48026.0
# 1                             0.0                   68750.0
# 2                             0.0                       0.0
# 3                         85417.0                   56894.0
# 4                             0.0                   50487.0
#
#    MEDIAN INCOME MIXED RACE  ...  population_haw_pac_islander_ratio  \
# 0                       0.0  ...                           0.001297
# 1                  197708.0  ...                           0.004943
# 2                       0.0  ...                           0.000000
# 3                   55625.0  ...                           0.003635
# 4                   50938.0  ...                           0.005052
#
#    population_other_ratio  population_mixed_ratio  \
# 0                0.006754                0.012212
# 1                0.000000                0.036039
# 2                0.000000                0.015291
# 3                0.001798                0.025032
# 4                0.000499                0.011816
#
#    population_hispanic_latino_ratio  Theft Count  latitude  longitude  \
# 0                          0.168153         79.0  32.78992 -116.71120
# 1                          0.459204         65.0  32.67400 -117.02100
# 2                          0.260242         11.0  32.70247 -116.50462
# 3                          0.599635        645.0  32.63700 -117.05000
# 4                          0.740116        561.0  32.61600 -117.03400
#
#    Substance Abuse Count  Violent Count  Miscellaneous Count
# 0                  317.0           50.0                 52.0
# 1                   24.0           19.0                 29.0
# 2                    4.0           15.0                  6.0
# 3                  251.0          304.0                273.0
# 4                  209.0          205.0                181.0
#
# [5 rows x 43 columns]

# %% [markdown]
# Four New Columns for Crime ratios are created which will standardize the count with the Zipcode population
# The new columns created are 'Theft Count Ratio', 'Substance Abuse Count Ratio', 'Violent Count Ratio' and 'Miscellaneous Count Ratio'

# %%
ca_school_data['Theft Count Ratio'] = ca_school_data['Theft Count'] / ca_school_data['POPULATION_TOTAL']
ca_school_data['Substance Abuse Count Ratio'] = ca_school_data['Substance Abuse Count'] / ca_school_data['POPULATION_TOTAL']
ca_school_data['Violent Count Ratio'] = ca_school_data['Violent Count'] / ca_school_data['POPULATION_TOTAL']
ca_school_data['Miscellaneous Count Ratio'] = ca_school_data['Miscellaneous Count'] / ca_school_data['POPULATION_TOTAL']
ca_school_data.head(75)
# Out:
#    zipcode  Total Students Enrolled  Average_School_Rating  \
# 0    91901                   1560.0               5.953846
# 1    91902                   1372.0               6.148688
# 2    91906                    454.0               4.279736
# 3    91910                  15136.0               6.237381
# 4    91911                  14330.0               5.293859
# ..     ...                      ...                    ...
# 70   92116                   1583.0               6.320278
# 71   92117                   6194.0               5.128350
# 72   92118                   3044.0               9.106767
# 73   92119                   2280.0               7.090351
# 74   92120                   5864.0               8.051671
#
#     MEDIAN HOUSEHOLD INCOME  MEDIAN INCOME BLACK/AA  \
# 0                   79859.0                143917.0
# 1                   86913.0                113875.0
# 2                   49276.0                     0.0
# 3                   53890.0                 54475.0
# 4                   49156.0                 42902.0
# ..                      ...                     ...
# 70                  56731.0                 51123.0
# 71                  65325.0                 39485.0
# 72                  90256.0                     0.0
# 73                  71071.0                 36875.0
# 74                  81718.0                 56581.0
#
#     MEDIAN INCOME INDIGENOUS PEOPLE  MEDIAN INCOME ASIAN  \
# 0                           53750.0              78625.0
# 1                               0.0              80192.0
# 2                           24306.0                  0.0
# 3                           43287.0              69688.0
# 4                           36932.0              77083.0
# ..                              ...                  ...
# 70                              0.0              55163.0
# 71                          78090.0              73320.0
# 72                              0.0             112500.0
# 73                              0.0              77875.0
# 74                         250001.0              64274.0
#
#     MEDIAN INCOME HAW/PAC ISLANDER  MEDIAN INCOME OTHER RACE  \
# 0                              0.0                   48026.0
# 1                              0.0                   68750.0
# 2                              0.0                       0.0
# 3                          85417.0                   56894.0
# 4                              0.0                   50487.0
# ..                             ...                       ...
# 70                             0.0                   35425.0
# 71                         49124.0                   51560.0
# 72                             0.0                   33750.0
# 73                             0.0                   39306.0
# 74                             0.0                   65278.0
#
#     MEDIAN INCOME MIXED RACE  ...  Theft Count  latitude  longitude  \
# 0                        0.0  ...         79.0  32.78992 -116.71120
# 1                   197708.0  ...         65.0  32.67400 -117.02100
# 2                        0.0  ...         11.0  32.70247 -116.50462
# 3                    55625.0  ...        645.0  32.63700 -117.05000
# 4                    50938.0  ...        561.0  32.61600 -117.03400
# ..                       ...  ...          ...       ...        ...
# 70                   45950.0  ...        228.0  32.76500 -117.12800
# 71                   68125.0  ...        347.0  32.81800 -117.19700
# 72                   72212.0  ...        124.0  32.67172 -117.16443
# 73                       0.0  ...        117.0  32.81600 -117.03300
# 74                   83500.0  ...        292.0  32.79500 -117.08000
#
#     Substance Abuse Count  Violent Count  Miscellaneous Count  \
# 0                   317.0           50.0                 52.0
# 1                    24.0           19.0                 29.0
# 2                     4.0           15.0                  6.0
# 3                   251.0          304.0                273.0
# 4                   209.0          205.0                181.0
# ..                    ...            ...                  ...
# 70                   29.0           50.0                 84.0
# 71                   80.0           99.0                117.0
# 72                   36.0           26.0                 66.0
# 73                   13.0           23.0                 38.0
# 74                   92.0           61.0                 89.0
#
#     Theft Count Ratio  Substance Abuse Count Ratio  Violent Count Ratio  \
# 0            0.004269                     0.017129             0.002702
# 1            0.003455                     0.001276             0.001010
# 2            0.003174                     0.001154             0.004328
# 3            0.008344                     0.003247             0.003933
# 4            0.006669                     0.002484             0.002437
# ..                ...                          ...                  ...
# 70           0.006886                     0.000876             0.001510
# 71           0.006489                     0.001496             0.001851
# 72           0.005406                     0.001569             0.001133
# 73           0.004822                     0.000536             0.000948
# 74           0.010761                     0.003390             0.002248
#
#     Miscellaneous Count Ratio
# 0                    0.002810
# 1                    0.001541
# 2                    0.001731
# 3                    0.003532
# 4                    0.002152
# ..                        ...
# 70                   0.002537
# 71                   0.002188
# 72                   0.002877
# 73                   0.001566
# 74                   0.003280
#
# [75 rows x 47 columns]

# %% [markdown]
# Removing the Crime Actual Counts from the dataframe i.e.
# 1. Theft Count
# 2. Substance Abuse Count
# 3. Violent Count
# 4. Miscellaneous Count

# %%
ca_school_data = ca_school_data.drop(labels=["Theft Count", "Substance Abuse Count","Violent Count","Miscellaneous Count"], axis=1)
ca_school_data.head(75)
# Out:
#    zipcode  Total Students Enrolled  Average_School_Rating  \
# 0    91901                   1560.0               5.953846
# 1    91902                   1372.0               6.148688
# 2    91906                    454.0               4.279736
# 3    91910                  15136.0               6.237381
# 4    91911                  14330.0               5.293859
# ..     ...                      ...                    ...
# 70   92116                   1583.0               6.320278
# 71   92117                   6194.0               5.128350
# 72   92118                   3044.0               9.106767
# 73   92119                   2280.0               7.090351
# 74   92120                   5864.0               8.051671
#
#     MEDIAN HOUSEHOLD INCOME  MEDIAN INCOME BLACK/AA  \
# 0                   79859.0                143917.0
# 1                   86913.0                113875.0
# 2                   49276.0                     0.0
# 3                   53890.0                 54475.0
# 4                   49156.0                 42902.0
# ..                      ...                     ...
# 70                  56731.0                 51123.0
# 71                  65325.0                 39485.0
# 72                  90256.0                     0.0
# 73                  71071.0                 36875.0
# 74                  81718.0                 56581.0
#
#     MEDIAN INCOME INDIGENOUS PEOPLE  MEDIAN INCOME ASIAN  \
# 0                           53750.0              78625.0
# 1                               0.0              80192.0
# 2                           24306.0                  0.0
# 3                           43287.0              69688.0
# 4                           36932.0              77083.0
# ..                              ...                  ...
# 70                              0.0              55163.0
# 71                          78090.0              73320.0
# 72                              0.0             112500.0
# 73                              0.0              77875.0
# 74                         250001.0              64274.0
#
#     MEDIAN INCOME HAW/PAC ISLANDER  MEDIAN INCOME OTHER RACE  \
# 0                              0.0                   48026.0
# 1                              0.0                   68750.0
# 2                              0.0                       0.0
# 3                          85417.0                   56894.0
# 4                              0.0                   50487.0
# ..                             ...                       ...
# 70                             0.0                   35425.0
# 71                         49124.0                   51560.0
# 72                             0.0                   33750.0
# 73                             0.0                   39306.0
# 74                             0.0                   65278.0
#
#     MEDIAN INCOME MIXED RACE  ...  population_haw_pac_islander_ratio  \
# 0                        0.0  ...                           0.001297
# 1                   197708.0  ...                           0.004943
# 2                        0.0  ...                           0.000000
# 3                    55625.0  ...                           0.003635
# 4                    50938.0  ...                           0.005052
# ..                       ...  ...                                ...
# 70                   45950.0  ...                           0.000000
# 71                   68125.0  ...                           0.006264
# 72                   72212.0  ...                           0.001875
# 73                       0.0  ...                           0.001731
# 74                   83500.0  ...                           0.001474
#
#     population_other_ratio  population_mixed_ratio  \
# 0                 0.006754                0.012212
# 1                 0.000000                0.036039
# 2                 0.000000                0.015291
# 3                 0.001798                0.025032
# 4                 0.000499                0.011816
# ..                     ...                     ...
# 70                0.002416                0.037964
# 71                0.002431                0.040859
# 72                0.001264                0.029339
# 73                0.001690                0.043396
# 74                0.000000                0.019937
#
#     population_hispanic_latino_ratio  latitude  longitude  Theft Count Ratio  \
# 0                           0.168153  32.78992 -116.71120           0.004269
# 1                           0.459204  32.67400 -117.02100           0.003455
# 2                           0.260242  32.70247 -116.50462           0.003174
# 3                           0.599635  32.63700 -117.05000           0.008344
# 4                           0.740116  32.61600 -117.03400           0.006669
# ..                               ...       ...        ...                ...
# 70                          0.261250  32.76500 -117.12800           0.006886
# 71                          0.219945  32.81800 -117.19700           0.006489
# 72                          0.143511  32.67172 -117.16443           0.005406
# 73                          0.170534  32.81600 -117.03300           0.004822
# 74                          0.170813  32.79500 -117.08000           0.010761
#
#     Substance Abuse Count Ratio  Violent Count Ratio  \
# 0                      0.017129             0.002702
# 1                      0.001276             0.001010
# 2                      0.001154             0.004328
# 3                      0.003247             0.003933
# 4                      0.002484             0.002437
# ..                          ...                  ...
# 70                     0.000876             0.001510
# 71                     0.001496             0.001851
# 72                     0.001569             0.001133
# 73                     0.000536             0.000948
# 74                     0.003390             0.002248
#
#     Miscellaneous Count Ratio
# 0                    0.002810
# 1                    0.001541
# 2                    0.001731
# 3                    0.003532
# 4                    0.002152
# ..                        ...
# 70                   0.002537
# 71                   0.002188
# 72                   0.002877
# 73                   0.001566
# 74                   0.003280
#
# [75 rows x 43 columns]

# %% [markdown]
# Removing the following columns from the dataframe i.e.
# 1. latitude
# 2. longitude

# %%
ca_school_drop = ca_school_data.drop(labels=["latitude", "longitude"], axis=1)
ca_school_drop.head(75)
# Out:
#    zipcode  Total Students Enrolled  Average_School_Rating  \
# 0    91901                   1560.0               5.953846
# 1    91902                   1372.0               6.148688
# 2    91906                    454.0               4.279736
# 3    91910                  15136.0               6.237381
# 4    91911                  14330.0               5.293859
# ..     ...                      ...                    ...
# 70   92116                   1583.0               6.320278
# 71   92117                   6194.0               5.128350
# 72   92118                   3044.0               9.106767
# 73   92119                   2280.0               7.090351
# 74   92120                   5864.0               8.051671
#
#     MEDIAN HOUSEHOLD INCOME  MEDIAN INCOME BLACK/AA  \
# 0                   79859.0                143917.0
# 1                   86913.0                113875.0
# 2                   49276.0                     0.0
# 3                   53890.0                 54475.0
# 4                   49156.0                 42902.0
# ..                      ...                     ...
# 70                  56731.0                 51123.0
# 71                  65325.0                 39485.0
# 72                  90256.0                     0.0
# 73                  71071.0                 36875.0
# 74                  81718.0                 56581.0
#
#     MEDIAN INCOME INDIGENOUS PEOPLE  MEDIAN INCOME ASIAN  \
# 0                           53750.0              78625.0
# 1                               0.0              80192.0
# 2                           24306.0                  0.0
# 3                           43287.0              69688.0
# 4                           36932.0              77083.0
# ..                              ...                  ...
# 70                              0.0              55163.0
# 71                          78090.0              73320.0
# 72                              0.0             112500.0
# 73                              0.0              77875.0
# 74                         250001.0              64274.0
#
#     MEDIAN INCOME HAW/PAC ISLANDER  MEDIAN INCOME OTHER RACE  \
# 0                              0.0                   48026.0
# 1                              0.0                   68750.0
# 2                              0.0                       0.0
# 3                          85417.0                   56894.0
# 4                              0.0                   50487.0
# ..                             ...                       ...
# 70                             0.0                   35425.0
# 71                         49124.0                   51560.0
# 72                             0.0                   33750.0
# 73                             0.0                   39306.0
# 74                             0.0                   65278.0
#
#     MEDIAN INCOME MIXED RACE  ...  population_indigenous_ratio  \
# 0                        0.0  ...                     0.018263
# 1                   197708.0  ...                     0.000957
# 2                        0.0  ...                     0.062320
# 3                    55625.0  ...                     0.001514
# 4                    50938.0  ...                     0.001426
# ..                       ...  ...                          ...
# 70                   45950.0  ...                     0.004168
# 71                   68125.0  ...                     0.004376
# 72                   72212.0  ...                     0.002616
# 73                       0.0  ...                     0.000618
# 74                   83500.0  ...                     0.002764
#
#     population_asian_ratio  population_haw_pac_islander_ratio  \
# 0                 0.011023                           0.001297
# 1                 0.088449                           0.004943
# 2                 0.011829                           0.000000
# 3                 0.098251                           0.003635
# 4                 0.065619                           0.005052
# ..                     ...                                ...
# 70                0.048505                           0.000000
# 71                0.107934                           0.006264
# 72                0.026505                           0.001875
# 73                0.053287                           0.001731
# 74                0.074701                           0.001474
#
#     population_other_ratio  population_mixed_ratio  \
# 0                 0.006754                0.012212
# 1                 0.000000                0.036039
# 2                 0.000000                0.015291
# 3                 0.001798                0.025032
# 4                 0.000499                0.011816
# ..                     ...                     ...
# 70                0.002416                0.037964
# 71                0.002431                0.040859
# 72                0.001264                0.029339
# 73                0.001690                0.043396
# 74                0.000000                0.019937
#
#     population_hispanic_latino_ratio  Theft Count Ratio  \
# 0                           0.168153           0.004269
# 1                           0.459204           0.003455
# 2                           0.260242           0.003174
# 3                           0.599635           0.008344
# 4                           0.740116           0.006669
# ..                               ...                ...
# 70                          0.261250           0.006886
# 71                          0.219945           0.006489
# 72                          0.143511           0.005406
# 73                          0.170534           0.004822
# 74                          0.170813           0.010761
#
#     Substance Abuse Count Ratio  Violent Count Ratio  \
# 0                      0.017129             0.002702
# 1                      0.001276             0.001010
# 2                      0.001154             0.004328
# 3                      0.003247             0.003933
# 4                      0.002484             0.002437
# ..                          ...                  ...
# 70                     0.000876             0.001510
# 71                     0.001496             0.001851
# 72                     0.001569             0.001133
# 73                     0.000536             0.000948
# 74                     0.003390             0.002248
#
#     Miscellaneous Count Ratio
# 0                    0.002810
# 1                    0.001541
# 2                    0.001731
# 3                    0.003532
# 4                    0.002152
# ..                        ...
# 70                   0.002537
# 71                   0.002188
# 72                   0.002877
# 73                   0.001566
# 74                   0.003280
#
# [75 rows x 41 columns]

# %%
# Using OneHotEncoder to create the features
# Generate our categorical variable lists
ca_school_cat = list(ca_school_drop.dtypes[ca_school_drop.dtypes == "object"].index)
ca_school_cat
# Out:
# ['zipcode']

# %%
ca_school_drop["zipcode"] = ca_school_drop["zipcode"].astype(str).astype(int)

ca_school_notnull_df = ca_school_drop.dropna()
ca_school_notnull_df
# Out:
#     zipcode  Total Students Enrolled  Average_School_Rating  \
# 0     91901                   1560.0               5.953846
# 1     91902                   1372.0               6.148688
# 2     91906                    454.0               4.279736
# 3     91910                  15136.0               6.237381
# 4     91911                  14330.0               5.293859
# ..      ...                      ...                    ...
# 85    92139                   4554.0               6.125604
# 86    92154                  14715.0               4.830921
# 87    92173                   4627.0               3.540739
# 88    92592                  16902.0               8.035262
# 89    92672                   3181.0               6.361207
#
#     MEDIAN HOUSEHOLD INCOME  MEDIAN INCOME BLACK/AA  \
# 0                   79859.0                143917.0
# 1                   86913.0                113875.0
# 2                   49276.0                     0.0
# 3                   53890.0                 54475.0
# 4                   49156.0                 42902.0
# ..                      ...                     ...
# 85                  58050.0                 56821.0
# 86                  60380.0                 52000.0
# 87                  35605.0                 71250.0
# 88                  89445.0                117550.0
# 89                  77829.0                     0.0
#
#     MEDIAN INCOME INDIGENOUS PEOPLE  MEDIAN INCOME ASIAN  \
# 0                           53750.0              78625.0
# 1                               0.0              80192.0
# 2                           24306.0                  0.0
# 3                           43287.0              69688.0
# 4                           36932.0              77083.0
# ..                              ...                  ...
# 85                         108333.0              65814.0
# 86                          75441.0              82632.0
# 87                              0.0              68194.0
# 88                         105932.0              98504.0
# 89                              0.0              92614.0
#
#     MEDIAN INCOME HAW/PAC ISLANDER  MEDIAN INCOME OTHER RACE  \
# 0                              0.0                   48026.0
# 1                              0.0                   68750.0
# 2                              0.0                       0.0
# 3                          85417.0                   56894.0
# 4                              0.0                   50487.0
# ..                             ...                       ...
# 85                             0.0                   75204.0
# 86                         84205.0                   59250.0
# 87                             0.0                   46225.0
# 88                             0.0                   78125.0
# 89                             0.0                   56964.0
#
#     MEDIAN INCOME MIXED RACE  ...  population_indigenous_ratio  \
# 0                        0.0  ...                     0.018263
# 1                   197708.0  ...                     0.000957
# 2                        0.0  ...                     0.062320
# 3                    55625.0  ...                     0.001514
# 4                    50938.0  ...                     0.001426
# ..                       ...  ...                          ...
# 85                   57601.0  ...                     0.000731
# 86                   68359.0  ...                     0.002163
# 87                   38750.0  ...                     0.000000
# 88                  108542.0  ...                     0.013188
# 89                  103520.0  ...                     0.001528
#
#     population_asian_ratio  population_haw_pac_islander_ratio  \
# 0                 0.011023                           0.001297
# 1                 0.088449                           0.004943
# 2                 0.011829                           0.000000
# 3                 0.098251                           0.003635
# 4                 0.065619                           0.005052
# ..                     ...                                ...
# 85                0.286809                           0.014783
# 86                0.126319                           0.003024
# 87                0.014526                           0.000185
# 88                0.098773                           0.003849
# 89                0.030981                           0.000594
#
#     population_other_ratio  population_mixed_ratio  \
# 0                 0.006754                0.012212
# 1                 0.000000                0.036039
# 2                 0.000000                0.015291
# 3                 0.001798                0.025032
# 4                 0.000499                0.011816
# ..                     ...                     ...
# 85                0.000244                0.036552
# 86                0.000476                0.025744
# 87                0.000000                0.004234
# 88                0.003307                0.043516
# 89                0.000764                0.025181
#
#     population_hispanic_latino_ratio  Theft Count Ratio  \
# 0                           0.168153           0.004269
# 1                           0.459204           0.003455
# 2                           0.260242           0.003174
# 3                           0.599635           0.008344
# 4                           0.740116           0.006669
# ..                               ...                ...
# 85                          0.411220           0.003439
# 86                          0.673187           0.007203
# 87                          0.947180           0.014403
# 88                          0.219026           0.000000
# 89                          0.227365           0.000000
#
#     Substance Abuse Count Ratio  Violent Count Ratio  \
# 0                      0.017129             0.002702
# 1                      0.001276             0.001010
# 2                      0.001154             0.004328
# 3                      0.003247             0.003933
# 4                      0.002484             0.002437
# ..                          ...                  ...
# 85                     0.000650             0.000948
# 86                     0.001857             0.004462
# 87                     0.003462             0.003276
# 88                     0.000013             0.000000
# 89                     0.000057             0.000000
#
#     Miscellaneous Count Ratio
# 0                    0.002810
# 1                    0.001541
# 2                    0.001731
# 3                    0.003532
# 4                    0.002152
# ..                        ...
# 85                   0.001625
# 86                   0.002061
# 87                   0.003554
# 88                   0.000013
# 89                   0.000000
#
# [87 rows x 41 columns]

# %%
ca_school_cat = list(ca_school_notnull_df.dtypes[ca_school_notnull_df.dtypes == "object"].index)
ca_school_cat
# Out:
# []

# %%
# Split our preprocessed data into our features and target arrays
X = ca_school_notnull_df.drop(["Average_School_Rating","zipcode"], axis=1).values
y = ca_school_notnull_df["Average_School_Rating"].values.reshape(-1, 1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
#hidden_nodes_layer3 = 300
#hidden_nodes_layer4 = 200
#hidden_nodes_layer5 = 100

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Fourth hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="sigmoid"))

# Fourth hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 80)                3200
# _________________________________________________________________
# dense_10 (Dense)             (None, 30)                2430
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 5,661
# Trainable params: 5,661
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adadelta", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.2861 - accuracy: 0.0000e+00
# Epoch 2/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.2878 - accuracy: 0.0000e+00
# Epoch 3/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.2898 - accuracy: 0.0000e+00
# Epoch 4/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.2919 - accuracy: 0.0000e+00
# Epoch 5/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.2935 - accuracy: 0.0000e+00
# Epoch 6/50
# 3/3 [==============================] - 0s 996us/step - loss: -0.2955 - accuracy: 0.0000e+00
# Epoch 7/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.2977 - accuracy: 0.0000e+00
# Epoch 8/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.2994 - accuracy: 0.0000e+00
# Epoch 9/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3011 - accuracy: 0.0000e+00
# Epoch 10/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3026 - accuracy: 0.0000e+00
# Epoch 11/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3047 - accuracy: 0.0000e+00
# Epoch 12/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3066 - accuracy: 0.0000e+00
# Epoch 13/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3084 - accuracy: 0.0000e+00
# Epoch 14/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3101 - accuracy: 0.0000e+00
# Epoch 15/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3121 - accuracy: 0.0000e+00
# Epoch 16/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3138 - accuracy: 0.0000e+00
# Epoch 17/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3157 - accuracy: 0.0000e+00
# Epoch 18/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3179 - accuracy: 0.0000e+00
# Epoch 19/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3197 - accuracy: 0.0000e+00
# Epoch 20/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3217 - accuracy: 0.0000e+00
# Epoch 21/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3237 - accuracy: 0.0000e+00
# Epoch 22/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3259 - accuracy: 0.0000e+00
# Epoch 23/50
# 3/3 [==============================] - 0s 997us/step - loss: -0.3276 - accuracy: 0.0000e+00
# Epoch 24/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3293 - accuracy: 0.0000e+00
# Epoch 25/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3314 - accuracy: 0.0000e+00
# Epoch 26/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3334 - accuracy: 0.0000e+00
# Epoch 27/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3351 - accuracy: 0.0000e+00
# Epoch 28/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3369 - accuracy: 0.0000e+00
# Epoch 29/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3389 - accuracy: 0.0000e+00
# Epoch 30/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3411 - accuracy: 0.0000e+00
# Epoch 31/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3431 - accuracy: 0.0000e+00
# Epoch 32/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3453 - accuracy: 0.0000e+00
# Epoch 33/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3474 - accuracy: 0.0000e+00
# Epoch 34/50
# 3/3 [==============================] - 0s 997us/step - loss: -0.3495 - accuracy: 0.0000e+00
# Epoch 35/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3518 - accuracy: 0.0000e+00
# Epoch 36/50
# 3/3 [==============================] - 0s 997us/step - loss: -0.3533 - accuracy: 0.0000e+00
# Epoch 37/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3551 - accuracy: 0.0000e+00
# Epoch 38/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3570 - accuracy: 0.0000e+00
# Epoch 39/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3590 - accuracy: 0.0000e+00
# Epoch 40/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3609 - accuracy: 0.0000e+00
# Epoch 41/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3632 - accuracy: 0.0000e+00
# Epoch 42/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3652 - accuracy: 0.0000e+00
# Epoch 43/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3671 - accuracy: 0.0000e+00
# Epoch 44/50
# 3/3 [==============================] - 0s 4ms/step - loss: -0.3693 - accuracy: 0.0000e+00
# Epoch 45/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3716 - accuracy: 0.0000e+00
# Epoch 46/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3736 - accuracy: 0.0000e+00
# Epoch 47/50
# 3/3 [==============================] - 0s 3ms/step - loss: -0.3754 - accuracy: 0.0000e+00
# Epoch 48/50
# 3/3 [==============================] - 0s 1ms/step - loss: -0.3773 - accuracy: 0.0000e+00
# Epoch 49/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3792 - accuracy: 0.0000e+00
# Epoch 50/50
# 3/3 [==============================] - 0s 2ms/step - loss: -0.3811 - accuracy: 0.0000e+00

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1/1 - 0s - loss: -4.0272e-01 - accuracy: 0.0000e+00
# Loss: -0.40271511673927307, Accuracy: 0.0
