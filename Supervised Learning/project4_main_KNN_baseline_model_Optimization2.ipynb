# %%
# Import Dependencies
import requests
import pandas as pd  
from sqlalchemy import create_engine
from config import remote_db_endpoint, remote_db_port
from config import remote_db_name, remote_db_user, remote_db_pwd
import numpy as np
from sqlalchemy import func
from sqlalchemy import distinct
import json
import psycopg2
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
cloud_engine = create_engine(f"postgresql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
cloud_conn = cloud_engine.connect()

ca_school_data = pd.read_sql('select * from ml_master_clean', cloud_conn)

ca_school_data.head()
# Out:
#    Zipcode  Total Students Enrolled  Median Household Income  \
# 0    91901                    244.0                  79859.0
# 1    91901                    333.0                  79859.0
# 2    91901                    438.0                  79859.0
# 3    91901                    387.0                  79859.0
# 4    91901                    158.0                  79859.0
#
#    Median Income BLACK/AA  Median Income INDIGENOUS PEOPLE  \
# 0                143917.0                          53750.0
# 1                143917.0                          53750.0
# 2                143917.0                          53750.0
# 3                143917.0                          53750.0
# 4                143917.0                          53750.0
#
#    Median Income ASIAN  Median Income HAW/PAC ISLANDER  \
# 0              78625.0                             0.0
# 1              78625.0                             0.0
# 2              78625.0                             0.0
# 3              78625.0                             0.0
# 4              78625.0                             0.0
#
#    Median Income OTHER RACE  Median Income MIXED RACE  \
# 0                   48026.0                       0.0
# 1                   48026.0                       0.0
# 2                   48026.0                       0.0
# 3                   48026.0                       0.0
# 4                   48026.0                       0.0
#
#    Median Income WHITE/NOT LATINO  ...  Substance Abuse Count  Violent Count  \
# 0                         88039.0  ...                  317.0           50.0
# 1                         88039.0  ...                  317.0           50.0
# 2                         88039.0  ...                  317.0           50.0
# 3                         88039.0  ...                  317.0           50.0
# 4                         88039.0  ...                  317.0           50.0
#
#    Miscellaneous Count              School Name  School Rating  \
# 0                 52.0      The Heights Charter            7.0
# 1                 52.0  Boulder Oaks Elementary            6.0
# 2                 52.0     Joan MacQueen Middle            6.0
# 3                 52.0  Shadow Hills Elementary            6.0
# 4                 52.0        Alpine Elementary            4.0
#
#                    School Address     City  Grades  Students Per Teacher  \
# 0  2710 Alpine Boulevard, Suite E   Alpine     K-8                  15:1
# 1                2320 Tavern Road   Alpine     1-5                  24:1
# 2                2001 Tavern Road   Alpine     6-8                  20:1
# 3       8770 Harbison Canyon Road   Alpine     K-5                  20:1
# 4           1850 Alpine Boulevard   Alpine     1-5                  20:1
#
#                   District
# 0        Dehesa Elementary
# 1  Alpine Union Elementary
# 2  Alpine Union Elementary
# 3  Alpine Union Elementary
# 4  Alpine Union Elementary
#
# [5 rows x 49 columns]

# %% [markdown]
# Four New Columns for Crime ratios are created which will standardize the count with the Zipcode population
# The new columns created are 'Theft Count Ratio', 'Substance Abuse Count Ratio', 'Violent Count Ratio' and 'Miscellaneous Count Ratio'

# %%
ca_school_data['Theft Count Ratio'] = ca_school_data['Theft Count'] / ca_school_data['Population Total']
ca_school_data['Substance Abuse Count Ratio'] = ca_school_data['Substance Abuse Count'] / ca_school_data['Population Total']
ca_school_data['Violent Count Ratio'] = ca_school_data['Violent Count'] / ca_school_data['Population Total']
ca_school_data['Miscellaneous Count Ratio'] = ca_school_data['Miscellaneous Count'] / ca_school_data['Population Total']
ca_school_data.head(75)
# Out:
#     Zipcode  Total Students Enrolled  Median Household Income  \
# 0     91901                    244.0                  79859.0
# 1     91901                    333.0                  79859.0
# 2     91901                    438.0                  79859.0
# 3     91901                    387.0                  79859.0
# 4     91901                    158.0                  79859.0
# ..      ...                      ...                      ...
# 70    91915                    332.0                 101760.0
# 71    91916                    211.0                  69821.0
# 72    91932                    896.0                  46659.0
# 73    91932                   1585.0                  46659.0
# 74    91932                    513.0                  46659.0
#
#     Median Income BLACK/AA  Median Income INDIGENOUS PEOPLE  \
# 0                 143917.0                          53750.0
# 1                 143917.0                          53750.0
# 2                 143917.0                          53750.0
# 3                 143917.0                          53750.0
# 4                 143917.0                          53750.0
# ..                     ...                              ...
# 70                109750.0                              0.0
# 71                     0.0                              0.0
# 72                 40521.0                          74773.0
# 73                 40521.0                          74773.0
# 74                 40521.0                          74773.0
#
#     Median Income ASIAN  Median Income HAW/PAC ISLANDER  \
# 0               78625.0                             0.0
# 1               78625.0                             0.0
# 2               78625.0                             0.0
# 3               78625.0                             0.0
# 4               78625.0                             0.0
# ..                  ...                             ...
# 70             101328.0                             0.0
# 71                  0.0                             0.0
# 72              41701.0                             0.0
# 73              41701.0                             0.0
# 74              41701.0                             0.0
#
#     Median Income OTHER RACE  Median Income MIXED RACE  \
# 0                    48026.0                       0.0
# 1                    48026.0                       0.0
# 2                    48026.0                       0.0
# 3                    48026.0                       0.0
# 4                    48026.0                       0.0
# ..                       ...                       ...
# 70                   82159.0                  121719.0
# 71                       0.0                       0.0
# 72                   37527.0                   36649.0
# 73                   37527.0                   36649.0
# 74                   37527.0                   36649.0
#
#     Median Income WHITE/NOT LATINO  ...  School Rating  \
# 0                          88039.0  ...            7.0
# 1                          88039.0  ...            6.0
# 2                          88039.0  ...            6.0
# 3                          88039.0  ...            6.0
# 4                          88039.0  ...            4.0
# ..                             ...  ...            ...
# 70                        117525.0  ...            4.0
# 71                         69955.0  ...            6.0
# 72                         57344.0  ...            6.0
# 73                         57344.0  ...            4.0
# 74                         57344.0  ...            3.0
#
#                     School Address             City  Grades  \
# 0   2710 Alpine Boulevard, Suite E           Alpine     K-8
# 1                 2320 Tavern Road           Alpine     1-5
# 2                 2001 Tavern Road           Alpine     6-8
# 3        8770 Harbison Canyon Road           Alpine     K-5
# 4            1850 Alpine Boulevard           Alpine     1-5
# ..                             ...              ...     ...
# 70      1949 Discovery Falls Drive      Chula Vista     6-8
# 71          24842 Viejas Boulevard         Descanso     K-6
# 72    650 Imperial Beach Boulevard   Imperial Beach     K-8
# 73                  505 Elm Avenue   Imperial Beach    9-12
# 74                1311 10th Street   Imperial Beach     K-6
#
#     Students Per Teacher                 District  Theft Count Ratio  \
# 0                   15:1        Dehesa Elementary           0.004269
# 1                   24:1  Alpine Union Elementary           0.004269
# 2                   20:1  Alpine Union Elementary           0.004269
# 3                   20:1  Alpine Union Elementary           0.004269
# 4                   20:1  Alpine Union Elementary           0.004269
# ..                   ...                      ...                ...
# 70                  14:1     SBC - High Tech High           0.003226
# 71                  21:1  Mountain Empire Unified           0.002483
# 72                  20:1          South Bay Union           0.004632
# 73                  25:1    Sweetwater Union High           0.004632
# 74                  20:1          South Bay Union           0.004632
#
#     Substance Abuse Count Ratio  Violent Count Ratio  \
# 0                      0.017129             0.002702
# 1                      0.017129             0.002702
# 2                      0.017129             0.002702
# 3                      0.017129             0.002702
# 4                      0.017129             0.002702
# ..                          ...                  ...
# 70                     0.000319             0.001489
# 71                     0.000000             0.000000
# 72                     0.006402             0.004406
# 73                     0.006402             0.004406
# 74                     0.006402             0.004406
#
#     Miscellaneous Count Ratio
# 0                    0.002810
# 1                    0.002810
# 2                    0.002810
# 3                    0.002810
# 4                    0.002810
# ..                        ...
# 70                   0.002340
# 71                   0.000000
# 72                   0.003126
# 73                   0.003126
# 74                   0.003126
#
# [75 rows x 53 columns]

# %% [markdown]
# Removing the Crime Actual Counts from the dataframe i.e.
# 1. Theft Count
# 2. Substance Abuse Count
# 3. Violent Count
# 4. Miscellaneous Count

# %%
ca_school_data = ca_school_data.drop(labels=["Theft Count", "Substance Abuse Count","Violent Count","Miscellaneous Count"], axis=1)
ca_school_data.head(75)
# Out:
#     Zipcode  Total Students Enrolled  Median Household Income  \
# 0     91901                    244.0                  79859.0
# 1     91901                    333.0                  79859.0
# 2     91901                    438.0                  79859.0
# 3     91901                    387.0                  79859.0
# 4     91901                    158.0                  79859.0
# ..      ...                      ...                      ...
# 70    91915                    332.0                 101760.0
# 71    91916                    211.0                  69821.0
# 72    91932                    896.0                  46659.0
# 73    91932                   1585.0                  46659.0
# 74    91932                    513.0                  46659.0
#
#     Median Income BLACK/AA  Median Income INDIGENOUS PEOPLE  \
# 0                 143917.0                          53750.0
# 1                 143917.0                          53750.0
# 2                 143917.0                          53750.0
# 3                 143917.0                          53750.0
# 4                 143917.0                          53750.0
# ..                     ...                              ...
# 70                109750.0                              0.0
# 71                     0.0                              0.0
# 72                 40521.0                          74773.0
# 73                 40521.0                          74773.0
# 74                 40521.0                          74773.0
#
#     Median Income ASIAN  Median Income HAW/PAC ISLANDER  \
# 0               78625.0                             0.0
# 1               78625.0                             0.0
# 2               78625.0                             0.0
# 3               78625.0                             0.0
# 4               78625.0                             0.0
# ..                  ...                             ...
# 70             101328.0                             0.0
# 71                  0.0                             0.0
# 72              41701.0                             0.0
# 73              41701.0                             0.0
# 74              41701.0                             0.0
#
#     Median Income OTHER RACE  Median Income MIXED RACE  \
# 0                    48026.0                       0.0
# 1                    48026.0                       0.0
# 2                    48026.0                       0.0
# 3                    48026.0                       0.0
# 4                    48026.0                       0.0
# ..                       ...                       ...
# 70                   82159.0                  121719.0
# 71                       0.0                       0.0
# 72                   37527.0                   36649.0
# 73                   37527.0                   36649.0
# 74                   37527.0                   36649.0
#
#     Median Income WHITE/NOT LATINO  ...  School Rating  \
# 0                          88039.0  ...            7.0
# 1                          88039.0  ...            6.0
# 2                          88039.0  ...            6.0
# 3                          88039.0  ...            6.0
# 4                          88039.0  ...            4.0
# ..                             ...  ...            ...
# 70                        117525.0  ...            4.0
# 71                         69955.0  ...            6.0
# 72                         57344.0  ...            6.0
# 73                         57344.0  ...            4.0
# 74                         57344.0  ...            3.0
#
#                     School Address             City  Grades  \
# 0   2710 Alpine Boulevard, Suite E           Alpine     K-8
# 1                 2320 Tavern Road           Alpine     1-5
# 2                 2001 Tavern Road           Alpine     6-8
# 3        8770 Harbison Canyon Road           Alpine     K-5
# 4            1850 Alpine Boulevard           Alpine     1-5
# ..                             ...              ...     ...
# 70      1949 Discovery Falls Drive      Chula Vista     6-8
# 71          24842 Viejas Boulevard         Descanso     K-6
# 72    650 Imperial Beach Boulevard   Imperial Beach     K-8
# 73                  505 Elm Avenue   Imperial Beach    9-12
# 74                1311 10th Street   Imperial Beach     K-6
#
#     Students Per Teacher                 District  Theft Count Ratio  \
# 0                   15:1        Dehesa Elementary           0.004269
# 1                   24:1  Alpine Union Elementary           0.004269
# 2                   20:1  Alpine Union Elementary           0.004269
# 3                   20:1  Alpine Union Elementary           0.004269
# 4                   20:1  Alpine Union Elementary           0.004269
# ..                   ...                      ...                ...
# 70                  14:1     SBC - High Tech High           0.003226
# 71                  21:1  Mountain Empire Unified           0.002483
# 72                  20:1          South Bay Union           0.004632
# 73                  25:1    Sweetwater Union High           0.004632
# 74                  20:1          South Bay Union           0.004632
#
#     Substance Abuse Count Ratio  Violent Count Ratio  \
# 0                      0.017129             0.002702
# 1                      0.017129             0.002702
# 2                      0.017129             0.002702
# 3                      0.017129             0.002702
# 4                      0.017129             0.002702
# ..                          ...                  ...
# 70                     0.000319             0.001489
# 71                     0.000000             0.000000
# 72                     0.006402             0.004406
# 73                     0.006402             0.004406
# 74                     0.006402             0.004406
#
#     Miscellaneous Count Ratio
# 0                    0.002810
# 1                    0.002810
# 2                    0.002810
# 3                    0.002810
# 4                    0.002810
# ..                        ...
# 70                   0.002340
# 71                   0.000000
# 72                   0.003126
# 73                   0.003126
# 74                   0.003126
#
# [75 rows x 49 columns]

# %% [markdown]
# Removing the following columns from the dataframe i.e.
# 1. latitude
# 2. longitude
# 3. School Address
# 4. City
# 5. Grades

# %% [markdown]
# Dropped additional columns Students Per Teacher, Total Students Enrolled, Zipcode, and District
# Also eliminated any onehot encoding since there were no categorical variables remaining

# %%
ca_school_drop = ca_school_data.drop(labels=["latitude", "longitude","School Name", "Grades","School Address","City","Students Per Teacher",
                                             "District","Zipcode","Total Students Enrolled","Median Income BLACK/AA", 'Median Income INDIGENOUS PEOPLE',
                                             'Median Income ASIAN','Median Income HAW/PAC ISLANDER'], axis=1)
ca_school_drop.head(75)
# Out:
#     Median Household Income  Median Income BLACK/AA  \
# 0                   79859.0                143917.0
# 1                   79859.0                143917.0
# 2                   79859.0                143917.0
# 3                   79859.0                143917.0
# 4                   79859.0                143917.0
# ..                      ...                     ...
# 70                 101760.0                109750.0
# 71                  69821.0                     0.0
# 72                  46659.0                 40521.0
# 73                  46659.0                 40521.0
# 74                  46659.0                 40521.0
#
#     Median Income INDIGENOUS PEOPLE  Median Income ASIAN  \
# 0                           53750.0              78625.0
# 1                           53750.0              78625.0
# 2                           53750.0              78625.0
# 3                           53750.0              78625.0
# 4                           53750.0              78625.0
# ..                              ...                  ...
# 70                              0.0             101328.0
# 71                              0.0                  0.0
# 72                          74773.0              41701.0
# 73                          74773.0              41701.0
# 74                          74773.0              41701.0
#
#     Median Income HAW/PAC ISLANDER  Median Income OTHER RACE  \
# 0                              0.0                   48026.0
# 1                              0.0                   48026.0
# 2                              0.0                   48026.0
# 3                              0.0                   48026.0
# 4                              0.0                   48026.0
# ..                             ...                       ...
# 70                             0.0                   82159.0
# 71                             0.0                       0.0
# 72                             0.0                   37527.0
# 73                             0.0                   37527.0
# 74                             0.0                   37527.0
#
#     Median Income MIXED RACE  Median Income WHITE/NOT LATINO  \
# 0                        0.0                         88039.0
# 1                        0.0                         88039.0
# 2                        0.0                         88039.0
# 3                        0.0                         88039.0
# 4                        0.0                         88039.0
# ..                       ...                             ...
# 70                  121719.0                        117525.0
# 71                       0.0                         69955.0
# 72                   36649.0                         57344.0
# 73                   36649.0                         57344.0
# 74                   36649.0                         57344.0
#
#     Median Income HISPANIC/LATINO  o25_10th_grade_attained_ratio  ...  \
# 0                         49500.0                       0.012959  ...
# 1                         49500.0                       0.012959  ...
# 2                         49500.0                       0.012959  ...
# 3                         49500.0                       0.012959  ...
# 4                         49500.0                       0.012959  ...
# ..                            ...                            ...  ...
# 70                        89612.0                       0.008781  ...
# 71                            0.0                       0.006108  ...
# 72                        41723.0                       0.022927  ...
# 73                        41723.0                       0.022927  ...
# 74                        41723.0                       0.022927  ...
#
#     Population asian ratio  Population haw/pac islander ratio  \
# 0                 0.011023                           0.001297
# 1                 0.011023                           0.001297
# 2                 0.011023                           0.001297
# 3                 0.011023                           0.001297
# 4                 0.011023                           0.001297
# ..                     ...                                ...
# 70                0.208302                           0.000000
# 71                0.014277                           0.004345
# 72                0.082282                           0.008887
# 73                0.082282                           0.008887
# 74                0.082282                           0.008887
#
#     Population other ratio  Population mixed ratio  \
# 0                 0.006754                0.012212
# 1                 0.006754                0.012212
# 2                 0.006754                0.012212
# 3                 0.006754                0.012212
# 4                 0.006754                0.012212
# ..                     ...                     ...
# 70                0.010777                0.033961
# 71                0.000000                0.015518
# 72                0.000226                0.039578
# 73                0.000226                0.039578
# 74                0.000226                0.039578
#
#     Population hispanic/latino ratio  School Rating  Theft Count Ratio  \
# 0                           0.168153            7.0           0.004269
# 1                           0.168153            6.0           0.004269
# 2                           0.168153            6.0           0.004269
# 3                           0.168153            6.0           0.004269
# 4                           0.168153            4.0           0.004269
# ..                               ...            ...                ...
# 70                          0.472544            4.0           0.003226
# 71                          0.120422            6.0           0.002483
# 72                          0.500998            6.0           0.004632
# 73                          0.500998            4.0           0.004632
# 74                          0.500998            3.0           0.004632
#
#     Substance Abuse Count Ratio  Violent Count Ratio  \
# 0                      0.017129             0.002702
# 1                      0.017129             0.002702
# 2                      0.017129             0.002702
# 3                      0.017129             0.002702
# 4                      0.017129             0.002702
# ..                          ...                  ...
# 70                     0.000319             0.001489
# 71                     0.000000             0.000000
# 72                     0.006402             0.004406
# 73                     0.006402             0.004406
# 74                     0.006402             0.004406
#
#     Miscellaneous Count Ratio
# 0                    0.002810
# 1                    0.002810
# 2                    0.002810
# 3                    0.002810
# 4                    0.002810
# ..                        ...
# 70                   0.002340
# 71                   0.000000
# 72                   0.003126
# 73                   0.003126
# 74                   0.003126
#
# [75 rows x 39 columns]

# %%
ca_school_updated = ca_school_drop

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split our preprocessed data into our features and target arrays
X = ca_school_updated.drop("School Rating", axis=1).values
y = ca_school_updated["School Rating"].values.reshape(-1, 1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Loop through different k values to find which has the highest accuracy.
# Note: We use only odd numbers because we don't want any ties.
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy score")
plt.show()
# Out:
# k: 1, Train/Test Score: 0.642/0.190
# k: 3, Train/Test Score: 0.466/0.207
# k: 5, Train/Test Score: 0.410/0.253
# k: 7, Train/Test Score: 0.406/0.224
# k: 9, Train/Test Score: 0.398/0.213
# k: 11, Train/Test Score: 0.387/0.241
# k: 13, Train/Test Score: 0.368/0.259
# k: 15, Train/Test Score: 0.358/0.247
# k: 17, Train/Test Score: 0.360/0.230
# k: 19, Train/Test Score: 0.354/0.264

# %%
# Note that k: 13 seems to be the best choice for this dataset
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train_scaled, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# k=13 Test Acc: 0.259

# %%
y_true = y_test
y_pred = knn.predict(X_test_scaled)

y_true = y_true.astype(np.int)
print(y_true)
y_true
df = pd.DataFrame({'true':y_true.flatten(),'pred':y_pred.flatten()})
df
# Out:
# [ 9  4  4  8  7  8  8  4  6  4  3  6  8  4  3  2  7  1  4  5  6  9  7  8
#   4  3  5  5  8 10  5  7  8  9  8  4  3  5  8  6  6  6  4  5  7  4  9  6
#   5  3  9  6  9  4  3  8  3  5  3  8  8  6  6  4  9  5  6  5  7  4  8  5
#   7  5  6  3  9  2  8  6  3  8  4  8  8  7  2  6  5  2  5  6  7  7  9  9
#   4  6  7  3  9  3  9  8  3  7  3 10  5  3  4  7  3  4  4  3  8  2  7  2
#  10 10  8  2  6  6  7  6  5  6  6  5  2  7  8  1  8  9  5  8  4  6  6  4
#   8  4  4  5  9  8  5  6  5  7  7  2  9  7  3  6  9  6  4  8  4  7  9  7
#   8  3  3  4  6  3]
#      true  pred
# 0       9   9.0
# 1       4   5.0
# 2       4   4.0
# 3       8   7.0
# 4       7   8.0
# ..    ...   ...
# 169     3   6.0
# 170     3   4.0
# 171     4   4.0
# 172     6   5.0
# 173     3   2.0
#
# [174 rows x 2 columns]
